# %%
import numpy as np
import pandas as pd
import hashlib
import os
import re
import xml.etree.ElementTree as ET

# %%
pd.set_option('display.max_colwidth', 1000)
#pd.set_option('display.width', 1000)

# %%
import xml.etree.ElementTree as ET
import pandas as pd


class GradeXML2DataFrame:

    def __init__(self, xml_data):
        xtree = ET.parse(xml_data)
        self.root = xtree.getroot()
        
    def extract_label(self, label_string):
        """Function that returns the class Id from original label string.
        0: correct
        1: correct_but_incomplete
        2: contradictory
        3: incorrect

        Args:
            label_string (String): original label in XML file

        Returns:
            class_id (Int): target class Id (0, 1, 2 or 3)
        """
        
        # Create list of all labels
        label_list = np.array(label_string.split('|'))
        # Keep only the label with flag (1)
        class_id = [i for i, s in enumerate(label_list) if "(1)" in s][0]
        return class_id
    
    
    def parse_instance(self, instance):
        """Reutrn a dictionary of instance attributes and their values."""
        
        info = {}
        info['instance_id'] = int(instance.attrib['ID'])
        for elem in instance:
            if elem.tag == 'MetaInfo':
                info['student_id'] = elem.attrib['StudentID']
                info['task_id'] = elem.attrib['TaskID']
            if elem.tag == 'Annotation':
                info['label'] = self.extract_label(elem.attrib['Label'])
            if elem.tag == 'ProblemDescription':
                info['problem_description'] = elem.text
            if elem.tag == 'Question':
                info['question'] = elem.text
            if elem.tag == 'Answer':
                info['answer'] = elem.text
            if elem.tag == 'ReferenceAnswers':
                info['reference_answers'] = re.sub('\n', ' ', elem.text.strip())
        return info
    
    
    def process_data(self):
        """Return a pandas dataframe containing all instances and their data."""
        instances = []
        for instance in self.root:
            info = self.parse_instance(instance)   
            instances.append(info) 
        columns = ["instance_id", "student_id", "task_id", "problem_description",
                   "question", "answer", "reference_answers", "label"]
        return pd.DataFrame(instances, columns=columns)
    

xml2df = GradeXML2DataFrame(os.path.join('data', 'grade_data.xml'))
data = xml2df.process_data()

# %%
data
# Out:
#      instance_id student_id                    task_id  \
# 0              1    DTSU040           LP03_PR09.bLK.sh
# 1              2    DTSU035            FM_LV04_PR05.sh
# 2              3    DTSU021               FM_LVxx_PR01
# 3              4    DTSU033           LP03_PR09.bLK.sh
# 4              5    DTSU015               FM_LV04_PR05
# ..           ...        ...                        ...
# 893          896    DTSU029               FM_LV03_PR07
# 894          897    DTSU009  LP03_PR12.push.accel.bMLK
# 895          898    DTSU034              LP03_PR09.bLK
# 896          899    DTSU020               FM_LV04_PR05
# 897          900    DTSU006            FM_LVxx_PR01.sh
#
#                                    problem_description  \
# 0    A car windshield collides with a mosquito, squ...
# 1    Two hockey players pass a puck between them on...
# 2    A rocket pushes a meteor with constant force. ...
# 3    A car windshield collides with a mosquito, squ...
# 4    Two hockey players pass a puck between them on...
# ..                                                 ...
# 893  A mover pushes a desk with a horizontal force ...
# 894  While speeding up, a large truck pushes a smal...
# 895  A car windshield collides with a mosquito, squ...
# 896  Two hockey players pass a puck between them on...
# 897  A rocket pushes a meteor with constant force. ...
#
#                                               question  \
# 0    How does Newton's third law apply to this situ...
# 1    What forces are acting on the puck while the p...
# 2              Can you articulate Newton's second law?
# 3    Can you articulate a principle or definition w...
# 4    Based on Newton's first law, what can you say ...
# ..                                                 ...
# 893      What can you say about the speed of the desk?
# 894  How does Newton's third law apply to this situ...
# 895  Can you articulate a principle or definition w...
# 896             Can you articulate Newton's first law?
# 897                          How will the meteor move?
#
#                                                 answer  \
# 0    the windshield will apply a force to the mosqu...
# 1    The normal force coming from the ice and the g...
# 2    if there is a zero net force on the object, th...
# 3    An equal force always balancing it out regardl...
# 4    The speed of the puck will equal to the net fo...
# ..                                                 ...
# 893  The speed of the desk will double because the ...
# 894  since the truck is a force pushing upon the ca...
# 895  the action and reaction forces here have to be...
# 896  an object will stay at rest or at constant vel...
# 897  The meteor will move with increasing speed due...
#
#                                      reference_answers  label
# 0    1:  Since the windshield exerts a force on the...      1
# 1    1:  The forces acting on the puck while it is ...      0
# 2    1:  Newton's 2nd Law says that the net force i...      3
# 3    1:  For every action, there is an equal and op...      3
# 4    1:  The puck will move in a straight line with...      3
# ..                                                 ...    ...
# 893  1:  The desk moves with increasing velocity. 2...      3
# 894  1:  The force from the car on the truck and th...      1
# 895  1:  For every action, there is an equal and op...      1
# 896  1:  An object at rest will stay at rest and at...      0
# 897  1:  Because there is a net force acting on the...      0
#
# [898 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
modeling, test = train_test_split(data, test_size=0.2, random_state=22)


if not os.path.exists("munge"):
    os.makedirs("munge")

modeling.to_csv(os.path.join("munge", "modeling.csv"), index=False)
test.to_csv(os.path.join("munge", "test.csv"), index=False)

# %%
train = pd.read_csv(os.path.join("munge", "train.csv"))

# %%
len(train)
# Out:
# 538

# %%
train
# Out:
#      instance_id student_id                 task_id  \
# 0            525    DTSU039  FM_LV04_PR10.FCI-16.sh
# 1            363    DTSU033         FM_LVxx_PR02.sh
# 2            560    DTSU019            FM_LV03_PR07
# 3            471    DTSU032            FF_LV02_PR02
# 4             27    DTSU019            FM_LV03_PR07
# ..           ...        ...                     ...
# 533          453    DTSU024            FM_LVxx_PR01
# 534           56    DTSU035         FM_LVxx_PR01.sh
# 535          524    DTSU025         FM_LV04_PR05.sh
# 536           87    DTSU019            FM_LVxx_PR01
# 537           35    DTSU040  FM_LV04_PR10.FCI-16.sh
#
#                                    problem_description  \
# 0    To rescue a child who has fallen down a well, ...
# 1    A rocket is pushing a meteor with constant for...
# 2    A mover pushes a desk with a horizontal force ...
# 3    A basketball player is dribbling a basketball ...
# 4    A mover pushes a desk with a horizontal force ...
# ..                                                 ...
# 533  A rocket pushes a meteor with constant force. ...
# 534  A rocket pushes a meteor with constant force. ...
# 535  Two hockey players pass a puck between them on...
# 536  A rocket pushes a meteor with constant force. ...
# 537  To rescue a child who has fallen down a well, ...
#
#                                               question  \
# 0               Can you articulate Newton's first law?
# 1    How will the meteor move after the rocket stop...
# 2    What can you say about the acceleration of the...
# 3    Because the ball's velocity is upward while th...
# 4        What can you say about the speed of the desk?
# ..                                                 ...
# 533  Given that the meteor starts at rest and then ...
# 534  Given that the meteor starts at rest and then ...
# 535  What forces are acting on the puck while the p...
# 536  Given the non-zero net force acting on the met...
# 537  How does the amount of tension in the rope com...
#
#                                                 answer  \
# 0    an object at rest or in motion will remain at ...
# 1    The meteor will continue to move at a constant...
# 2    The acceleration and speed of the desk both in...
# 3                           THE VELOCITY IS DECREASING
# 4    When the force on the desk is doubles, the des...
# ..                                                 ...
# 533           The meteor's velocity will be increasing
# 534  The metor's motion is linear and that the magn...
# 535  Gravity is acting on the puck as it is moving ...
# 536  It says that the meteor is at a constant accel...
# 537                                  they are the same
#
#                                      reference_answers  label
# 0    1:  An object at rest will stay at rest and at...      1
# 1    1:  When the rocket stops pushing, no forces a...      1
# 2    1:  The desk will move with constant accelerat...      2
# 3    1:  The ball is slowing down at a constant rat...      0
# 4    1:  The desk moves with increasing velocity. 2...      3
# ..                                                 ...    ...
# 533  1:  The meteor will move with increasing veloc...      0
# 534  1:  The meteor will move with increasing veloc...      0
# 535  1:  The forces acting on the puck while it is ...      1
# 536  1:  Because there is a net force acting on the...      0
# 537  1:  Since the child is being raised straight u...      0
#
# [538 rows x 8 columns]

# %%
def read_train():
    return pd.read_csv(os.path.join("munge", "train.csv"))

# %%
train = read_train()

# %%
train.head()
# Out:
#    instance_id student_id                 task_id  \
# 0          525    DTSU039  FM_LV04_PR10.FCI-16.sh
# 1          363    DTSU033         FM_LVxx_PR02.sh
# 2          560    DTSU019            FM_LV03_PR07
# 3          471    DTSU032            FF_LV02_PR02
# 4           27    DTSU019            FM_LV03_PR07
#
#                                  problem_description  \
# 0  To rescue a child who has fallen down a well, ...
# 1  A rocket is pushing a meteor with constant for...
# 2  A mover pushes a desk with a horizontal force ...
# 3  A basketball player is dribbling a basketball ...
# 4  A mover pushes a desk with a horizontal force ...
#
#                                             question  \
# 0             Can you articulate Newton's first law?
# 1  How will the meteor move after the rocket stop...
# 2  What can you say about the acceleration of the...
# 3  Because the ball's velocity is upward while th...
# 4      What can you say about the speed of the desk?
#
#                                               answer  \
# 0  an object at rest or in motion will remain at ...
# 1  The meteor will continue to move at a constant...
# 2  The acceleration and speed of the desk both in...
# 3                         THE VELOCITY IS DECREASING
# 4  When the force on the desk is doubles, the des...
#
#                                    reference_answers  label
# 0  1:  An object at rest will stay at rest and at...      1
# 1  1:  When the rocket stops pushing, no forces a...      1
# 2  1:  The desk will move with constant accelerat...      2
# 3  1:  The ball is slowing down at a constant rat...      0
# 4  1:  The desk moves with increasing velocity. 2...      3

# %%
def get_hash(string):
    return hashlib.md5(string.encode()).hexdigest()[:10]

# %%
train['pd_hash'] = train['problem_description'].apply(get_hash)

# %%
train['qu_hash'] = train['question'].apply(get_hash)

# %%
def extract_reference_answers(reference_answers):
    """Functions that returns a cleaned list of reference answers.

    Args:
        reference_answers (String): Original reference answers in XML file

    Returns:
        ra_list (list): reference answers separated in a list
    """

    # Split on new line character
    ra_list = reference_answers.split(':') 
    # Delete unecessary answer numbers
    ra_list = [re.sub('[0-9]+', '', ra).strip() for ra in ra_list] 
    # Remove empty elements
    ra_list = [ra for ra in ra_list if ra != '']
    return ra_list

train['ra_list'] = train['reference_answers'].apply(extract_reference_answers)

# %%
train
# Out:
#      instance_id student_id                 task_id  \
# 0            525    DTSU039  FM_LV04_PR10.FCI-16.sh
# 1            363    DTSU033         FM_LVxx_PR02.sh
# 2            560    DTSU019            FM_LV03_PR07
# 3            471    DTSU032            FF_LV02_PR02
# 4             27    DTSU019            FM_LV03_PR07
# ..           ...        ...                     ...
# 533          453    DTSU024            FM_LVxx_PR01
# 534           56    DTSU035         FM_LVxx_PR01.sh
# 535          524    DTSU025         FM_LV04_PR05.sh
# 536           87    DTSU019            FM_LVxx_PR01
# 537           35    DTSU040  FM_LV04_PR10.FCI-16.sh
#
#                                    problem_description  \
# 0    To rescue a child who has fallen down a well, ...
# 1    A rocket is pushing a meteor with constant for...
# 2    A mover pushes a desk with a horizontal force ...
# 3    A basketball player is dribbling a basketball ...
# 4    A mover pushes a desk with a horizontal force ...
# ..                                                 ...
# 533  A rocket pushes a meteor with constant force. ...
# 534  A rocket pushes a meteor with constant force. ...
# 535  Two hockey players pass a puck between them on...
# 536  A rocket pushes a meteor with constant force. ...
# 537  To rescue a child who has fallen down a well, ...
#
#                                               question  \
# 0               Can you articulate Newton's first law?
# 1    How will the meteor move after the rocket stop...
# 2    What can you say about the acceleration of the...
# 3    Because the ball's velocity is upward while th...
# 4        What can you say about the speed of the desk?
# ..                                                 ...
# 533  Given that the meteor starts at rest and then ...
# 534  Given that the meteor starts at rest and then ...
# 535  What forces are acting on the puck while the p...
# 536  Given the non-zero net force acting on the met...
# 537  How does the amount of tension in the rope com...
#
#                                                 answer  \
# 0    an object at rest or in motion will remain at ...
# 1    The meteor will continue to move at a constant...
# 2    The acceleration and speed of the desk both in...
# 3                           THE VELOCITY IS DECREASING
# 4    When the force on the desk is doubles, the des...
# ..                                                 ...
# 533           The meteor's velocity will be increasing
# 534  The metor's motion is linear and that the magn...
# 535  Gravity is acting on the puck as it is moving ...
# 536  It says that the meteor is at a constant accel...
# 537                                  they are the same
#
#                                      reference_answers  label     pd_hash  \
# 0    1:  An object at rest will stay at rest and at...      1  5059c9cfbb
# 1    1:  When the rocket stops pushing, no forces a...      1  abb3be1545
# 2    1:  The desk will move with constant accelerat...      2  d0331a86c9
# 3    1:  The ball is slowing down at a constant rat...      0  a5b241c8bc
# 4    1:  The desk moves with increasing velocity. 2...      3  d0331a86c9
# ..                                                 ...    ...         ...
# 533  1:  The meteor will move with increasing veloc...      0  b78a60db07
# 534  1:  The meteor will move with increasing veloc...      0  b78a60db07
# 535  1:  The forces acting on the puck while it is ...      1  35db126042
# 536  1:  Because there is a net force acting on the...      0  b78a60db07
# 537  1:  Since the child is being raised straight u...      0  5059c9cfbb
#
#         qu_hash                                            ra_list
# 0    27570f5d10  [An object at rest will stay at rest and at ob...
# 1    c9b7df0ef8  [When the rocket stops pushing, no forces are ...
# 2    37b9d25827  [The desk will move with constant acceleration...
# 3    52e3695922  [The ball is slowing down at a constant rate.,...
# 4    64a1152f6d  [The desk moves with increasing velocity., The...
# ..          ...                                                ...
# 533  a40ba67403  [The meteor will move with increasing velocity...
# 534  a40ba67403  [The meteor will move with increasing velocity...
# 535  178bc99915  [The forces acting on the puck while it is bet...
# 536  99e24777b0  [Because there is a net force acting on the me...
# 537  71fc865756  [Since the child is being raised straight upwa...
#
# [538 rows x 11 columns]

# %%
landmarks_ra = train[['pd_hash', 'qu_hash', 'label', 'ra_list']].explode('ra_list').rename(columns={'ra_list':'answer'})
landmarks_ra['label'] = 0 # these are possible correct answers (class id 0)
landmarks_ra = landmarks_ra.drop_duplicates()
print("Found {} distinct reference answer landmarks.".format(len(landmarks_ra)))
landmarks_a = train[['pd_hash', 'qu_hash', 'label', 'answer']].drop_duplicates()
print("Found {} distinct student answer landmarks.".format(len(landmarks_a)))
landmarks = landmarks_ra.append(landmarks_a).drop_duplicates()
print("Found {} distinct landmarks in total.".format(len(landmarks)))
# Out:
# Found 224 distinct reference answer landmarks.
# Found 537 distinct student answer landmarks.
# Found 760 distinct landmarks in total.

# %%
train[(train['pd_hash']=='a5b241c8bc') & (train['qu_hash']=='e712984405')]
# Out:
#      instance_id student_id          task_id                                                                             problem_description                                                                                                                                                                question                                                                                                                                                                                                                                                                                                                                                                                              answer  \
# 6            232    DTSU019     FF_LV02_PR02  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                         The acceleration at this point is at its highest point, and the forces acting on it are gravity and the normal forces from the floor that is pushing the ball back up to the player's hand.
# 36           145    DTSU018     FF_LV02_PR02  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                     When the ball is moving upward, it has a normal force, the force of gravity and it continues upwards to hit its peak to gain a velocity of zero
# 70           535    DTSU002  FF_LV02_PR02.sh  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                                                       There is the force of gravity and the force applied from the player's hand. The motion of the ball is upward.
# 84           262    DTSU021     FF_LV02_PR02  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                                                                    the basketball is in free fall, therefore the only force acting on it is the gravitational force
# 124           62    DTSU032     FF_LV02_PR02  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                                                                                                                                THE FORCE OF GRAVITY IS ACTING ON IT
# 130          573    DTSU007  FF_LV02_PR02.sh  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                               When the ball is midway between the player's hand and the ground, the gravitational force from the earth is acting on the ball, as well as the force from the bounce.
# 135          330    DTSU026  FF_LV02_PR02.sh  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                                                                            a downward force from the hand, a gravitational force and a normal force from the ground
# 153          234    DTSU016  FF_LV02_PR02.sh  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                                                                             When it is moving upward, and in the air. The only force acting on the ball is gravity.
# 208          606    DTSU034     FF_LV02_PR02  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                                         when the ball is moving upwards, there is the force of gravity and the force that was applied when the ball hit the ground.
# 242          406    DTSU014  FF_LV02_PR02.sh  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                        the forces of gravity and the push from the floor are acting upon the ball. The motion of the ball is upwards and towards the player's hand.
# 286          877    DTSU009     FF_LV02_PR02  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                                      The force from the ground after the ball hits it, the velocity of the ball after it hits the ground. The ball is moving upward
# 296          288    DTSU015     FF_LV02_PR02  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                              The forces that are acting on the ball is the earth's gravitational pull on the ball and the basketball player's push on the basketball to the ground.
# 346           74    DTSU022     FF_LV02_PR02  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                                                                                                      Normal force and gravitational force are acting on the object.
# 388          169    DTSU039  FF_LV02_PR02.sh  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                                                                                           the force that was exerted by the floor when the ball bounced and gravity
# 401          659    DTSU011     FF_LV02_PR02  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                                                                            Graviational force is acting on the ball and its speed is decreasing at a constant rate.
# 449          532    DTSU012  FF_LV02_PR02.sh  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.  When the ball is moving upward, a downward force caused by gravity is acting on the ball. There is also a normal force, otherwise known as a ground reaction force, acting upward on the ball. While the ball is midway between the player's hand and the ground, the ball is moving upward. This is happened because the normal force is GREATER than the gravitational force acting on the ball.
# 487          110    DTSU038     FF_LV02_PR02  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                                                             When the ball is moving upward it is in free-fall and it is affected by the Earth's gravitational pull.
# 524           59    DTSU013     FF_LV02_PR02  A basketball player is dribbling a basketball (continuously bouncing the ball off the ground).  What forces are acting on the ball when it is moving upward and it is midway between the player's hand and the ground? Describe the motion of the ball at that moment.                                                                                                                                                                                                                                                              The forces acting on the ball are gravity and the normal force from the ball. The ball moves verticallt upward at a constant velocity.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            reference_answers  \
# 6    1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 36   1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 70   1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 84   1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 124  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 130  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 135  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 153  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 208  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 242  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 286  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 296  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 346  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 388  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 401  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 449  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 487  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
# 524  1:  Gravity is the only force acting on the ball. The ball is slowing down at a constant rate. 2:  Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down. 3:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down. 4:  Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing. 5:  Gravity is the only force acting on the ball. The ball's velocity is decreasing. 6:  Gravity is the only force acting on the ball. The ball is slowing down. 7:  The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate. 8:  The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing ...
#
#      label     pd_hash     qu_hash  \
# 6        3  a5b241c8bc  e712984405
# 36       3  a5b241c8bc  e712984405
# 70       2  a5b241c8bc  e712984405
# 84       1  a5b241c8bc  e712984405
# 124      1  a5b241c8bc  e712984405
# 130      2  a5b241c8bc  e712984405
# 135      3  a5b241c8bc  e712984405
# 153      1  a5b241c8bc  e712984405
# 208      3  a5b241c8bc  e712984405
# 242      3  a5b241c8bc  e712984405
# 286      3  a5b241c8bc  e712984405
# 296      3  a5b241c8bc  e712984405
# 346      3  a5b241c8bc  e712984405
# 388      3  a5b241c8bc  e712984405
# 401      0  a5b241c8bc  e712984405
# 449      2  a5b241c8bc  e712984405
# 487      1  a5b241c8bc  e712984405
# 524      3  a5b241c8bc  e712984405
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ra_list
# 6    [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 36   [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 70   [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 84   [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 124  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 130  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 135  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 153  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 208  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 242  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 286  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 296  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 346  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 388  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 401  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 449  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 487  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...
# 524  [Gravity is the only force acting on the ball. The ball is slowing down at a constant rate., Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down., Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball's velocity is decreasing., Gravity is the only force acting on the ball. The ball is slowing down., The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate., The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down., The only force ac...

# %%
landmarks.head()
# Out:
#       pd_hash     qu_hash  label                                                                                                                                                                                                                                                   answer
# 0  5059c9cfbb  27570f5d10      0                                 An object at rest will stay at rest and at object moving with constant velocity in a straight line will continue moving with constant velocity in a straight line as long as the net force acting on the object is zero.
# 0  5059c9cfbb  27570f5d10      0  If all the forces acting on an object add up to zero (accounting for the direction of the forces and not just their magnitude) then the acceleration of that object also has to be zero. It can move at a constant speed but it cannot be accelerating.
# 0  5059c9cfbb  27570f5d10      0                                                                                                                                                            When the object is in equilibrium or velocity is constant, the sum of all forces will equal .
# 1  abb3be1545  c9b7df0ef8      0                                                                                                             When the rocket stops pushing, no forces are acting on the meteor anymore and therefore will move with constant velocity in a straight line.
# 1  abb3be1545  c9b7df0ef8      0                                                                                                                                                           When the rocket stops pushing, the meteor will move with constant velocity in a straight line.

# %%
from gensim.models import KeyedVectors

print('Indexing word vectors..')

embedding_file = os.path.join("munge", "GoogleNews-vectors-negative300.bin")
word2vec = KeyedVectors.load_word2vec_format(embedding_file, binary=True)

print('Found %s word vectors of word2vec' % len(word2vec.vocab))
# Out:
# Indexing word vectors..
# Found 3000000 word vectors of word2vec

# %%
word2vec.doesnt_match("second 2nd third".split())
# Out:
# /anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# '2nd'

# %%
word2vec.most_similar("decreasing")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-194-bfcc56c5b7dc> in <module>
# ----> 1 word2vec.most_similar("decreasing")
#
# /anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     562
#     563         limited = self.vectors_norm if restrict_vocab is None else self.vectors_norm[:restrict_vocab]
# --> 564         dists = dot(limited, mean)
#     565         if not topn:
#     566             return dists
#
# KeyboardInterrupt:

# %%
word2vec.most_similar("2nd")
# Out:
# [('3rd', 0.9359426498413086),
#  ('4th', 0.9051286578178406),
#  ('1st', 0.9043662548065186),
#  ('5th', 0.8837502002716064),
#  ('6th', 0.8750925064086914),
#  ('7th', 0.8689243793487549),
#  ('8th', 0.8483569622039795),
#  ('9th', 0.8367735147476196),
#  ('3_rd', 0.7579688429832458),
#  ('##st', 0.7001097202301025)]

# %%
# Enrich the punctuation
import string
punctuation = string.punctuation
punctuation = punctuation + "’" + "“" + "?" + "‘"
print(punctuation)

def removePunctuation(phrase):
    """
    Removes punctuation, changes to lower case, strips leading, middle and trailing spaces.

    Note:
        Only spaces, letters, and numbers are retained.  Other characters are eliminated (e.g. it's becomes its).
        Leading, middle and trailing spaces are removed after punctuation is removed.

    Args:
        phrase (String): A String containing a sentence.

    Returns:
        nopun: A String with clean-up operation applied.
    """
    
    nopunc = ''.join([c if c not in punctuation else ' ' for c in phrase])
    nopunc = re.sub(r'\s+', ' ', nopunc)
    return nopunc.lower()


# Stemming, functions
import re

def tokenize(phrase):
    """
    Produces a list of tokens from a character string

    Args:
        phrase (String): A character string.

    Returns:
        tokenized: A List of tokens.
    """ 
    
    tokenized = phrase.split()
    
    return tokenized


def filterVocab(tokens):
    tokens = [token for token in tokens if token in word2vec.vocab]
    return tokens


def preprocess(phrase):
    
    return filterVocab(tokenize(removePunctuation(phrase)))
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~’“?‘

# %%
phrase1 = preprocess("2nd law")
phrase2 = preprocess("second law")
word2vec.n_similarity(phrase1, phrase2)
# Out:
# 0.82781506

# %%
phrase1 = preprocess("2nd law")
phrase2 = preprocess("third law")
word2vec.n_similarity(phrase1, phrase2)
# Out:
# 0.8073168

# %%
phrase1 = preprocess("2nd law")
phrase2 = preprocess("3rd law")
word2vec.n_similarity(phrase1, phrase2)
# Out:
# 0.9695801

# %%
phrase1 = preprocess("2nd law")
phrase2 = preprocess("Newton's 3rd law applies as a non-zero net force acts on the desk")
word2vec.n_similarity(phrase1, phrase2)
# Out:
# 0.51169366

# %%
def get_embeddings(tokens):
    
    emb = np.zeros(300)
    if len(tokens) > 0:
        nb_tokens = 0
        for token in tokens:
            emb += word2vec.word_vec(token)
            nb_tokens += 1
        emb /= nb_tokens
    return np.array(emb)

get_embeddings(preprocess("2nd law"))
# Out:
# array([ 0.07080078,  0.02709961,  0.0925293 ,  0.12402344, -0.03125   ,
#        -0.09716797, -0.15527344,  0.00256348,  0.05187988,  0.02008057,
#        -0.00878906, -0.05255127, -0.16296387,  0.11401367, -0.23657227,
#         0.03515625,  0.11669922, -0.05908203, -0.14794922, -0.12719727,
#         0.09008789, -0.05316162,  0.03417969,  0.00268555,  0.00823975,
#        -0.20117188,  0.03417587, -0.06323242, -0.0322876 ,  0.25292969,
#        -0.08447266, -0.23583984,  0.00073242, -0.06878662,  0.02758789,
#        -0.00549316,  0.06286621,  0.18359375, -0.04824829,  0.09750366,
#        -0.03515625, -0.03369141,  0.01000977,  0.11010742, -0.01611328,
#         0.13696289,  0.03872681, -0.03405762, -0.08227539,  0.02685547,
#         0.07202148, -0.02441406,  0.15454102,  0.21679688, -0.03469849,
#         0.13208008,  0.00598145, -0.00634766, -0.16455078, -0.1595459 ,
#        -0.0300293 , -0.18066406, -0.00170898, -0.21801758, -0.203125  ,
#         0.11395264,  0.15429688,  0.02093506,  0.03515625,  0.1776123 ,
#         0.11508179, -0.03710938,  0.08508301,  0.05212402,  0.01342773,
#        -0.04431152, -0.20605469,  0.12145996,  0.26220703, -0.12463379,
#         0.05203247,  0.02661133,  0.00634766, -0.08642578,  0.05419922,
#        -0.10083008,  0.01416016,  0.27978516,  0.02471924,  0.08825684,
#         0.13757324, -0.03456116,  0.05834961, -0.08376312, -0.1114502 ,
#         0.0880127 ,  0.03466797, -0.17138672,  0.17382812,  0.10107422,
#        -0.12841797, -0.22998047, -0.07958984, -0.1315918 ,  0.0244751 ,
#        -0.0319519 , -0.06311035, -0.19458008, -0.07519531, -0.14990234,
#         0.11767578,  0.06860352, -0.15966797,  0.02563477,  0.09937286,
#         0.00683594, -0.01733398, -0.01123047,  0.07763672,  0.12988281,
#        -0.11071777, -0.01489258, -0.00616455,  0.08545685,  0.19921875,
#        -0.06672668, -0.06103516, -0.06958008,  0.16455078,  0.0383606 ,
#         0.11120605, -0.16918945, -0.11938477, -0.04486084, -0.12255859,
#        -0.01855469, -0.03765869, -0.00228882, -0.00415039,  0.04345703,
#         0.09301758,  0.10961914,  0.03735352, -0.10319519, -0.20458984,
#         0.00488281, -0.12120819,  0.17578125,  0.00805664, -0.01806641,
#         0.13427734,  0.04223633, -0.02667236,  0.04125977, -0.06802368,
#         0.04492188,  0.02197266, -0.02587891, -0.06689453, -0.12207031,
#        -0.12963867, -0.04559326,  0.16210938, -0.10302734,  0.02661133,
#         0.04724121,  0.21630859, -0.00585938,  0.07098389, -0.15625   ,
#        -0.22265625, -0.07107925,  0.04888916, -0.14233398, -0.05331421,
#        -0.00488281,  0.04614258, -0.0994873 ,  0.0625    , -0.10839844,
#        -0.14648438, -0.08679199, -0.02587891,  0.15332031, -0.1105957 ,
#        -0.06298828,  0.26757812,  0.12695312,  0.20848083,  0.01519775,
#        -0.07495117,  0.16772461,  0.07202148,  0.04980469,  0.10302734,
#        -0.01855469, -0.00854492,  0.04241943,  0.20703125, -0.15332031,
#        -0.10292053,  0.09277344,  0.07348633, -0.08496094, -0.03930664,
#         0.02563477,  0.0513916 , -0.02151489, -0.09790039, -0.02880859,
#        -0.19702148,  0.30566406, -0.02197266, -0.11938477, -0.06787109,
#         0.109375  , -0.07702637, -0.0291748 , -0.05200195, -0.2010498 ,
#        -0.15490723, -0.03503418,  0.19555664,  0.08349609, -0.04272461,
#        -0.21582031,  0.10571289,  0.09594727, -0.08129883, -0.03222656,
#         0.07354736,  0.20019531, -0.15722656,  0.03076172, -0.00854492,
#         0.09388733,  0.19580078, -0.10919189,  0.03485107,  0.10003662,
#        -0.11132812, -0.09667969,  0.06443024,  0.06652832,  0.00286865,
#         0.05151367,  0.02368164,  0.16358948,  0.07092285, -0.18310547,
#        -0.06433105, -0.04521561, -0.07116699, -0.0994873 ,  0.07411957,
#        -0.03857422, -0.08276367,  0.08895874,  0.04077148, -0.06982422,
#         0.08071899, -0.03100586, -0.12731934,  0.01147461,  0.04541016,
#         0.05078125, -0.08886719, -0.0677948 , -0.26464844, -0.02832031,
#         0.04833984,  0.07067871,  0.06298828,  0.05517578, -0.11254883,
#        -0.17822266, -0.12207031, -0.05560303, -0.16381836,  0.07189941,
#        -0.07250977,  0.03809071,  0.04211426,  0.22998047,  0.12011719,
#        -0.14990234, -0.05340576,  0.07820129,  0.03459549,  0.11987305,
#         0.05255127, -0.13745117, -0.01708984, -0.07519531, -0.04956055,
#         0.05322266, -0.13256836, -0.15844727,  0.1182251 , -0.00280762])

# %%
landmarks.iloc[5]['answer']
# Out:
# 'The meteor will move with constant velocity in a straight line.'

# %%
from numpy import dot
from numpy.linalg import norm

def cossim(a, b):
    return dot(a,b) / (norm(a) * norm(b))

for i in range(len(landmarks)):
    emb1 = get_embeddings(preprocess("2nd law"))
    emb2 = get_embeddings(preprocess(landmarks.iloc[i]['answer']))
    print(i, cossim(emb1, emb2), landmarks.iloc[i]['answer'])
# Out:
# 0 0.20921653410389637 An object at rest will stay at rest and at object moving with constant velocity in a straight line will continue moving with constant velocity in a straight line as long as the net force acting on the object is zero.
# 1 0.21318218677528852 If all the forces acting on an object add up to zero (accounting for the direction of the forces and not just their magnitude) then the acceleration of that object also has to be zero. It can move at a constant speed but it cannot be accelerating.
# 2 0.1923720223360516 When the object is in equilibrium or velocity is constant, the sum of all forces will equal .
# 3 0.2137879921148141 When the rocket stops pushing, no forces are acting on the meteor anymore and therefore will move with constant velocity in a straight line.
# 4 0.18871505938040894 When the rocket stops pushing, the meteor will move with constant velocity in a straight line.
# 5 0.18486718771924596 The meteor will move with constant velocity in a straight line.
# 6 0.22661824353845583 The meteor will move at a constant speed in the same direction in a straight line.
# 7 0.1684801093545444 The desk will move with constant acceleration and the speed will increase.
# 8 0.2287639076730998 The desk increases its speed as the net force is non-zero.
# 9 0.18338146213244574 The ball is slowing down at a constant rate.
# 10 0.17400157253287554 Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down.
# 11 0.2216234263188726 Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down.
# 12 0.20202289732171974 Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing.
# 13 0.16159558550711758 The ball's velocity is decreasing.
# 14 0.1928777507153572 The ball is slowing down.
# 15 0.14226635912457458 The desk moves with increasing velocity.
# 16 0.1684801093545444 The desk will move with constant acceleration and the speed will increase.
# 17 0.2287639076730998 The desk increases its speed as the net force is non-zero.
# 18 0.2355733664153219 The desk increases its speed as the net force is not zero anymore.
# 19 0.2599559862092928 Since the child is being raised straight upward at a constant speed, the net force on the child is zero and all the forces balance. That means that the tension in the rope balances the downward force of gravity.
# 20 0.19101992697714062 The force of gravity and tension in the rope are balanced.
# 21 0.15449094828287313 All forces balance.
# 22 0.1384057861209579 The gravity and the tension balance.
# 23 0.24636669834179964 The net force on the kid is zero.
# 24 0.24050525907447623 Gravity is the only force acting on the ball. The ball is slowing down at a constant rate.
# 25 0.21391387840717208 Gravity is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down.
# 26 0.24471897438747237 Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down.
# 27 0.2315156531896882 Gravity is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing.
# 28 0.23239469651207234 Gravity is the only force acting on the ball. The ball's velocity is decreasing.
# 29 0.24830952510359566 Gravity is the only force acting on the ball. The ball is slowing down.
# 30 0.24984256177128375 The only force acting on the ball is the downward force of gravity. The ball is slowing down at a constant rate.
# 31 0.2207416632974235 The only force acting on the ball is the downward force of gravity. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down.
# 32 0.251043279746221 The only force acting on the ball is the downward force of gravity. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down.
# 33 0.23946162131795862 The only force acting on the ball is the downward force of gravity. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing.
# 34 0.2442720063816334 The only force acting on the ball is the downward force of gravity. The ball's velocity is decreasing.
# 35 0.25734913440663737 The only force acting on the ball is the downward force of gravity. The ball is slowing down.
# 36 0.24033699805391975 The ball's weight is the only force acting on the ball. The ball is slowing down at a constant rate.
# 37 0.21684428817155557 The ball's weight is the only force acting on the ball. Since the ball's velocity is upward and its acceleration is downward, the ball is slowing down.
# 38 0.24299874756080345 The ball's weight is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball is slowing down.
# 39 0.23089187143967638 The ball's weight is the only force acting on the ball. The ball's velocity is decreasing.
# 40 0.2311185613039322 The ball's weight is the only force acting on the ball. Since the ball's acceleration is in the opposite direction of it's velocity, the ball's velocity is decreasing.
# 41 0.24521003704629027 The ball's weight is the only force acting on the ball. The ball is slowing down.
# 42 0.2599559862092928 Since the child is being raised straight upward at a constant speed, the net force on the child is zero and all the forces balance. That means that the tension in the rope balances the downward force of gravity.
# 43 0.15449094828287313 All forces balance.
# 44 0.2142633217244085 The amount of tension in the rope is the same as the magnitude of the downward force of gravity.
# 45 0.2135270745293323 The amount of tension in the rope is equal to the magnitude of the downward force of gravity.
# 46 0.22064884659189002 The amount of tension in the rope is the same as the child's weight.
# 47 0.22008088777027315 The amount of tension in the rope is equal to the child's weight.
# 48 0.2044797616553209 The force of gravity and tension in the rope balance.
# 49 0.1751828350705454 The force of gravity and tension in the rope have equal magnitudes.
# 50 0.22568354005245578 The forces are the force of the mover pushing on the box, the force of friction from the floor on the box, the gravitational force from the earth on the box, and the normal force from the floor on the box. The force of friction balances the force of the mover pushing.
# 51 0.2169424102516864 The forces are the force of the mover pushing on the box, the force of friction from the floor on the box, the gravitational force from the earth on the box, and the normal force from the floor on the box. Friction balances the push.
# 52 0.2262906756048039 The forces are the force of the mover pushing on the box, the force of friction from the floor on the box, the gravitational force from the earth on the box, and the normal force from the floor on the box. The force of the mover pushing and the force of friction balance each other.
# 53 0.22927886625446126 The forces are the force of the mover pushing on the box, the force of friction from the floor on the box, the gravitational force from the earth on the box, and the normal force from the floor on the box. The normal force from the floor on the box balances the gravitational force from the earth on the box.
# 54 0.22946035359938485 The forces are the force of the mover pushing on the box, the force of friction from the floor on the box, the gravitational force from the earth on the box, and the normal force from the floor on the box. The normal force balances gravity.
# 55 0.2317313887669996 The forces are the force of the mover pushing on the box, the force of friction from the floor on the box, the gravitational force from the earth on the box, and the normal force from the floor on the box. The normal force and the gravitational force balance each other.
# 56 0.18774881290718112 The forces are mover on box, friction from floor on box, the gravity from earth on box, and the normal from floor on box. The force of friction balances the force of the mover pushing.
# 57 0.16089744315695376 The forces are mover on box, friction from floor on box, the gravity from earth on box, and the normal from floor on box. Friction balances the push.
# 58 0.1904143640522301 The forces are mover on box, friction from floor on box, the gravity from earth on box, and the normal from floor on box. The force of the mover pushing and the force of friction balance each other.
# 59 0.19870713772247636 The forces are mover on box, friction from floor on box, the gravity from earth on box, and the normal from floor on box. The normal force from the floor on the box balances the gravitational force from the earth on the box.
# 60 0.18205197816332294 The forces are mover on box, friction from floor on box, the gravity from earth on box, and the normal from floor on box. The normal force balances gravity.
# 61 0.19684294380268977 The forces are mover on box, friction from floor on box, the gravity from earth on box, and the normal from floor on box. The normal force and the gravitational force balance each other.
# 62 0.1357740251559963 push, friction, gravity, normal. The force of friction balances the force of the mover pushing.
# 63 0.05576761728460225 push, friction, gravity, normal. Friction balances the push.
# 64 0.14669117093913978 push, friction, gravity, normal. The force of the mover pushing and the force of friction balance each other.
# 65 0.11289580151666694 push, friction, gravity, normal. The normal force balances gravity.
# 66 0.19811831665584287 push, friction, gravity, normal. The normal force from the floor on the box balances the gravitational force from the earth on the box.
# 67 0.15491457633439018 push, friction, gravity, normal. The normal force and the gravitational force balance each other.
# 68 0.24023752753256047 Because the net force on the desk is zero, the mover's push balances the opposing force of friction.
# 69 0.2403817152010329 Because the net force on the desk is zero, the force of push on the desk by the mover has the same magnitude but opposite direction to the force friction.
# 70 0.2549417709942851 Because the net force on the desk is zero, the mover's push is equal and opposite to the force of friction acting on the desk.
# 71 0.1673046712064093 The mover's push equals the opposing force of friction.
# 72 0.06613038334458923 Mover's push equals friction.
# 73 0.13841056163763668 The meteor will move with increasing velocity.
# 74 0.18293945264078676 The meteor moves with constant acceleration and its velocity will keep increasing in the direction of the force as long as the rocket pushes.
# 75 0.17290870298782146 Because the meteor's acceleration is constant while the rocket pushes, the meteor will move with increasing velocity.
# 76 0.16114841638872845 The meteor will speed up.
# 77 0.16213932678640033 The meteor's speed will increase.
# 78 0.13203666235227204 The meteor will move faster and faster.
# 79 0.23251352096832514 The forces acting on the puck while it is between the players are the downward force of gravity and the upward normal force from the ice. The puck will move in a straight line with a constant speed.
# 80 0.2333298682246867 The forces acting on the puck while it is between the players are the downward force of gravity and the upward normal force from the ice.  These two forces balance each other out as the puck is at rest in the vertical direction. The puck will move in a straight line with a constant speed.
# 81 0.2302359890954339 The forces acting on the puck are the downward force of gravity and the upward normal force from the ice. The puck will move in a straight line with a constant speed.
# 82 0.21649558543907088 The forces acting on the puck are weight and the upward normal force from the ice. The puck will move in a straight line with a constant speed.
# 83 0.22955590611271898 For every action, there is an equal and opposite reaction.
# 84 0.30761218189812006 Whenever one object exerts a force on a second object, the second object exerts an equal and opposite force on the first
# 85 0.4398861231552772 According to Newton's third law, for every action, there is an equal and opposite reaction.
# 86 0.20921653410389637 An object at rest will stay at rest and at object moving with constant velocity in a straight line will continue moving with constant velocity in a straight line as long as the net force acting on the object is zero.
# 87 0.21318218677528852 If all the forces acting on an object add up to zero (accounting for the direction of the forces and not just their magnitude) then the acceleration of that object also has to be zero. It can move at a constant speed but it cannot be accelerating.
# 88 0.1923720223360516 When the object is in equilibrium or velocity is constant, the sum of all forces will equal .
# 89 0.2462873449955263 Since there are no forces acting on the puck in the horizontal direction, the net horizontal force is zero.
# 90 0.2133530272301286 The net horizontal force is zero.
# 91 0.21415438169618742 The force of gravity and the tension in the rope balance.
# 92 0.08412350164812529 The gravity and tension have equal magnitudes.
# 93 0.4248267285124517 Newton's nd Law says that the net force is equal to the product of the mass and the acceleration.
# 94 0.218762006692613 An object on which a net force is being applied will move with a constant acceleration that is inversely proportional to the object's mass and that has the same direction as the force.
# 95 0.12144381083876885 The net force equals mass times acceleration.
# 96 0.3985115998054003 Newton's second law says that net force equals mass times acceleration.
# 97 0.09834546504482347 The sum of the forces equals mass times acceleration.
# 98 0.18412644574157225 The sum of all the forces acting on an object, divided by its mass is equivalent to the acceleration of that object
# 99 0.2508853180991152 Because there is a net force acting on the meteor, which is the same as the push from the rocket as no other forces are acting on it, the meteor will move with a non-zero acceleration in the direction of the net force.
# 100 0.358492191641014 The push from the rocket makes the meteor move with a non-zero acceleration, according to Newton's second law.
# 101 0.34665330455662463 According to Newton's second law, the push from the rocket will make the meteor move with constant acceleration in the direction of the force.
# 102 0.15654140761999566 The push from the rocket will make the meteor move with increasing velocity.
# 103 0.3777039726350715 According to Newton's second law, a non-zero net force means a non-zero acceleration in the direction of the net force.
# 104 0.18383011129144416 The push from the rocket will make the meteor move with constant acceleration in the direction of the push.
# 105 0.16122754340720732 The push from the rocket will make the meteor move with constant acceleration.
# 106 0.13535761641478666 The acceleration of the meteor is constant.
# 107 0.29669510092357154 The net or total force on the meteor is the same as the push from the rocket as no other forces are acting on the meteor. According to Newton's second law, the pushing force from the rocket will make the meteor move with constant acceleration in the direction of that force.
# 108 0.13841056163763668 The meteor will move with increasing velocity.
# 109 0.18293945264078676 The meteor moves with constant acceleration and its velocity will keep increasing in the direction of the force as long as the rocket pushes.
# 110 0.17290870298782146 Because the meteor's acceleration is constant while the rocket pushes, the meteor will move with increasing velocity.
# 111 0.16114841638872845 The meteor will speed up.
# 112 0.16213932678640033 The meteor's speed will increase.
# 113 0.13203666235227204 The meteor will move faster and faster.
# 114 0.3621996779564396 The force from the car on the truck and the force from the truck on the car are a Third Law pair. Thus, the forces are equal in magnitude and opposite in direction.
# 115 0.21446479132952254 The amount of forces exerted by the truck and car are equal.
# 116 0.24464675396817448 The forces from the truck and car are equal and opposite.
# 117 0.2776515880436075 The force from the truck and the force from the car are equal and opposite.
# 118 0.16416135249581632 The forces are equal in magnitude.
# 119 0.24565071414931233 Since the windshield exerts a force on the mosquito, which we can call action, the mosquito exerts an equal and opposite force on the windshield, called the reaction.
# 120 0.22866857496023232 The action  is the windshield squashing the mosquito, and the equal and opposite reaction is the mosquito hitting the windshield.
# 121 0.3363986094336302 The force exerted by the windshield on the mosquito and the force exerted by the mosquito on the windshield are a third-law pair of action and reaction.
# 122 0.23079797606202765 The force exerted by the windshield on the mosquito and the force exerted by the mosquito on the windshield are an action-reaction pair.
# 123 0.18910921153971655 The amounts of the two forces are equal.
# 124 0.1828140213859981 The amounts of the action and reaction forces are equal.
# 125 0.24565071414931233 Since the windshield exerts a force on the mosquito, which we can call action, the mosquito exerts an equal and opposite force on the windshield, called the reaction.
# 126 0.22866857496023232 The action  is the windshield squashing the mosquito, and the equal and opposite reaction is the mosquito hitting the windshield.
# 127 0.3363986094336302 The force exerted by the windshield on the mosquito and the force exerted by the mosquito on the windshield are a third-law pair of action and reaction.
# 128 0.23079797606202765 The force exerted by the windshield on the mosquito and the force exerted by the mosquito on the windshield are an action-reaction pair
# 129 0.2508853180991152 Because there is a net force acting on the meteor, which is the same as the push from the rocket as no other forces are acting on it, the meteor will move with a non-zero acceleration in the direction of the net force.
# 130 0.358492191641014 The push from the rocket makes the meteor move with a non-zero acceleration, according to Newton's second law.
# 131 0.34665330455662463 According to Newton's second law, the push from the rocket will make the meteor move with constant acceleration in the direction of the force.
# 132 0.15654140761999566 The push from the rocket will make the meteor move with increasing velocity.
# 133 0.3777039726350715 According to Newton's second law, a non-zero net force means a non-zero acceleration in the direction of the net force.
# 134 0.18383011129144416 The push from the rocket will make the meteor move with constant acceleration in the direction of the push.
# 135 0.16122754340720732 The push from the rocket will make the meteor move with constant acceleration.
# 136 0.13535761641478666 The acceleration of the meteor is constant.
# 137 0.29669510092357154 The net or total force on the meteor is the same as the push from the rocket as no other forces are acting on the meteor. According to Newton's second law, the pushing force from the rocket will make the meteor move with constant acceleration in the direction of that force
# 138 0.2137879921148141 When the rocket stops pushing, no forces are acting on the meteor anymore and therefore will move with constant velocity in a straight line
# 139 0.37356677822961337 The first law is relevant because the problem asks about motion when no forces (that is, zero net force) are acting on an object.
# 140 0.35368670856123935 The first law is relevant because the problem involves an object on which no forces are acting.
# 141 0.3682122460043485 The first law is relevant because the problem involves the meteor on which no forces are acting.
# 142 0.42339751087677335 The first law is relevant because there is a zero net force acting on the meteor.
# 143 0.21105133203724952 An object at rest will stay at rest and an object moving with constant velocity in a straight line will continue moving with constant velocity in a straight line as long as the net force acting on the object is zero.
# 144 0.1923720223360516 When the object is in equilibrium or velocity is constant, the sum of all forces will equal .
# 145 0.2329596269774951 If the acceleration of a system is zero, the summation of the forces is also zero.
# 146 0.13203666235227204 The meteor will move faster and faster
# 147 0.06613038334458923 Mover's push equals friction
# 148 0.28597744383466006 The first law is relevant because the problem describes an object moving with constant velocity which means the object's acceleration is zero.
# 149 0.32043333320030737 The first law is relevant because the problem involves an object moving with constant velocity.
# 150 0.2834219237725822 The first law is relevant because the problem involves an object moving with zero acceleration which means the velocity of the object is constant.
# 151 0.38124327695370935 Newton's first law is useful because the desk moves with constant velocity.
# 152 0.19435825787949598 When the object is in equilibrium or velocity is constant, the sum of all forces will equal zero.
# 153 0.1749875639188739 The force of friction balances the force of the mover pushing.
# 154 0.0601067996179689 Friction balances the push.
# 155 0.18539386081877482 The force of the mover pushing and the force of friction balance each other
# 156 0.42339751087677335 The first law is relevant because there is a zero net force acting on the meteor
# 157 0.22625286699648975 The force exerted by the windshield on the mosquito and the force exerted by the mosquito on the windshield are equal.
# 158 0.3656619632674329 When the mover doubles his force, the push is greater than friction resulting in a non-zero net force acting on the desk and so Newton's second law can be applied.
# 159 0.4796427416895906 Newton's second law applies as there is a non-zero net force.
# 160 0.4792114194540885 Newton's nd law applies as a non-zero net force acts on the desk
# 161 0.5723806449522667 Newton's nd law is relevant.
# 162 0.1923720223360516 When the object is in equilibrium or velocity is constant, the sum of all forces will equal
# 163 0.2329596269774951 If the acceleration of a system is zero, the summation of the forces is also zero
# 164 0.20044717438878643 The puck will move in a straight line with a constant speed.
# 165 0.22660089805107098 The normal force from the floor on the box balances the gravitational force from the earth on the box.
# 166 0.16172021053267277 The normal force balances gravity.
# 167 0.19927164576015524 The normal force and the gravitational force balance each other
# 168 0.3795283329824898 The second law is relevant because the problem describes a non-zero net force being applied on an object.
# 169 0.34629817339569036 The second law is relevant because the problem describes a non-zero net force, which is the push from the rocket, being applied on an object, which is the meteor in this case.
# 170 0.4283090601871911 The second law is relevant because the net force acting on the meteor is non-zero.
# 171 0.37784111852490326 The second law is relevant because the meteor is being pushed by the rocket.
# 172 0.40801867129161296 The second law is relevant because the meteor exerts a force on the rocket.
# 173 0.4074045307922187 The Newton's second law is relevant because the rocket exerts a net force on the meteor.
# 174 0.2142633217244085 The amount of tension in the rope is the same as the magnitude of the downward force of gravity.
# 175 0.2135270745293323 The amount of tension in the rope is equal to the magnitude of the downward force of gravity.
# 176 0.22064884659189002 The amount of tension in the rope is the same as the child's weight.
# 177 0.22008088777027315 The amount of tension in the rope is equal to the child's weight.
# 178 0.15951356448653284 The force of gravity and tension balance.
# 179 0.08412350164812529 The gravity and tension have equal magnitudes
# 180 0.08124380351713878 Acceleration has both magnitude and direction.
# 181 0.1132432907057443 Acceleration tells you both magnitude and direction.
# 182 0.3621996779564396 The force from the car on the truck and the force from the truck on the car are a Third Law pair. Thus, the forces are equal in magnitude and opposite in direction.
# 183 0.23244906394609036 The forces exerted by the truck and car are equal and opposite.
# 184 0.24464675396817448 The forces from the truck and car are equal and opposite.
# 185 0.2776515880436075 The force from the truck and the force from the car are equal and opposite.
# 186 0.2657518909786993 The force from the truck and the force from the car form action reaction pair.
# 187 0.22716750705675728 The forces are the force of the mover pushing on the box, the force of friction from the floor on the box, the gravitational force from the earth on the box, and the normal force from the floor on the box.
# 188 0.16685878262567727 The forces are mover on box, friction from floor on box, the gravity from earth on box, and the normal from floor on box.
# 189 0.044807479042831735 push, friction, gravity, normal
# 190 0.2290515185160517 The mover's push, when doubled, is larger than the opposing force of friction resulting in a non-zero force.
# 191 0.18175491003779026 Puck moves in a straight line with a constant speed.
# 192 0.25493571047160934 Since gravity is the only force acting on the ball, the net force on the ball is downward, so the ball's acceleration must also be downward.
# 193 0.17003841111887108 The ball's acceleration is downward.
# 194 0.2200063993221197 The direction of the ball's acceleration is the same the downward force of gravity.
# 195 0.21494677501078777 The direction of the ball's acceleration is the same as the downward direction of the force.
# 196 0.2273367002040628 The forces acting on the puck while it is between the players are the downward force of gravity and the upward normal force from the ice.
# 197 0.23048353989982173 The forces acting on the puck while it is between the players are the downward force of gravity and the upward normal force from the ice.  These two forces balance each other out as the puck is at rest in the vertical direction
# 198 0.23620559122041784 The forces acting on the puck are the force of gravity and the normal force from the ice.
# 199 0.22955590611271898 For every action, there is an equal and opposite reaction.
# 200 0.30761218189812006 Whenever one object exerts a force on a second object, the second object exerts an equal and opposite force on the first
# 201 0.4398861231552772 According to Newton's third law, for every action, there is an equal and opposite reaction.
# 202 0.14226635912457458 The desk moves with increasing velocity.
# 203 0.1684801093545444 The desk will move with constant acceleration and the speed will increase.
# 204 0.2287639076730998 The desk increases its speed as the net force is non-zero.
# 205 0.2355733664153219 The desk increases its speed as the net force is not zero anymore.
# 206 0.23244906394609036 The forces exerted by the truck and car are equal and opposite.
# 207 0.22651899154983027 The amount of forces from the truck and car are equal.
# 208 0.16133211019012936 The amounts of the forces are equal.
# 209 0.2536909492207656 The force from the truck and the force from the car are form action reaction pair.
# 210 0.20921653410389637 An object at rest will stay at rest and at object moving with constant velocity in a straight line will continue moving with constant velocity in a straight line as long as the net force acting on the object is zero.
# 211 0.21318218677528852 If all the forces acting on an object add up to zero (accounting for the direction of the forces and not just their magnitude) then the acceleration of that object also has to be zero. It can move at a constant speed but it cannot be accelerating.
# 212 0.1923720223360516 When the object is in equilibrium or velocity is constant, the sum of all forces will equal
# 213 0.30761218189812006 Whenever one object exerts a force on a second object, the second object exerts an equal and opposite force on the first.
# 214 0.24353741133494422 The direction of the ball's acceleration is the same with that of the force.
# 215 0.24353741133494422 the direction of the ball's acceleration is the same with that of the force.
# 216 0.21937901963695156 Since the box is moving with a constant velocity, the net force on the box is zero and all the forces on the box balance.
# 217 0.20869994643289702 The box moves with constant velocity, so there no net force on the box
# 218 0.18910921153971655 The amounts of the two forces are equal.
# 219 0.1828140213859981 The amounts of the action and reaction forces are equal.
# 220 0.22625286699648975 The force exerted by the windshield on the mosquito and the force exerted by the mosquito on the windshield are equal.
# 221 0.06776416641243403 Gravity and tension are balanced.
# 222 0.2200063993221197 the direction of the ball's acceleration is the same the downward force of gravity.
# 223 0.20934483259593714 same as the downward direction of the force
# 224 0.2596582865891239 an object at rest or in motion will remain at rest or in motion unless acted on by an outside force
# 225 0.13687648599479943 The meteor will continue to move at a constant velocity.
# 226 0.17363811990424335 The acceleration and speed of the desk both increase
# 227 0.10855630166840499 THE VELOCITY IS DECREASING
# 228 0.24518538698160863 When the force on the desk is doubles, the desk will begin to accelerate until it reaches a constant velocity again.
# 229 0.16829968326521189 the kid is moving at a constant velocity in a straight line
# 230 0.23965179407253126 The acceleration at this point is at its highest point, and the forces acting on it are gravity and the normal forces from the floor that is pushing the ball back up to the player's hand.
# 231 0.24504586447589097 The tension force minus the weight of the child is what compares the downward force of gravity acting on the child.
# 232 0.21291722247247086 MOVER APPLIES GREADER FORCE TO THE OBJECT THAN THE OPPOSING FORCE OF FRICTION. nORMAL FORCE AND FORCE OF GRAVITY ARE ZERO
# 233 0.1738096186396526 the magnitude of the mover's push is greater than that of the opposing force of friction
# 234 0.1750131653720728 It's dispacement grows exponetially
# 235 0.10874942021456414 gravity, the normal force, and friction
# 236 0.4602681020900249 newton's third law states that every action has an equal but opposite reaction force
# 237 0.4279845751666465 Newton's first law states that every object will not move unless there is a force acting upon it
# 238 0.19896069920258794 the net horizontal force is positive since there is no friction
# 239 0.11197327006806629 They are equal.
# 240 0.25022679356364286 OBJECT IN MOTION STAYS IN MOTION
# 241 0.12144381083876885 The net force equals mass times acceleration
# 242 0.21032966465337571 The meteor will continue to accelerate due to the rocket's continual applied force. The acceleration will cause the meteor's velocity to continue to increase until a force is no longer applied by the rocket.
# 243 0.20636368254758666 The forces the truck and car exert on each other are constant.
# 244 0.20748466758515002 Both the mosquito and the wondshield are exerting a force on each other but the windshield is exerting a greater force on the mosquito due to acceleration
# 245 0.25367628072717086 the force applied by misquito is balanced by the reaction force from the windshield
# 246 0.4226145305623367 Newton's second law states force is equal to mass times acceleration.
# 247 0.06279864401891097 TRAVELS AT A CONSTANT ACCELERATION
# 248 0.21545067825897513 The force exerted on the mosquito by the windshield is greated than the force exerted on the windshield by the mosquito
# 249 0.12932612027278828 Yes
# 250 0.5464288894328605 2ND LAW, OBJECTS IN MOTION CONTINUE TO STAY IN MOTION
# 251 0.5406116638966959 Newton's first law is relevant.
# 252 0.1344207694942659 that the acceleration will be constant
# 253 0.37944996869005687 newton's first law is force is equal to mass times acceleration
# 254 0.20013852032608398 it will accelerate in the direction of the push
# 255 0.24127943751418296 that the meteor's motion will be increasing in speed as time expires
# 256 0.19527006092830923 The two forces of the mover pushing and friction ballenced each other out until the mover started to push with a larger force.
# 257 0.15841466221233302 only a frictional force is applied
# 258 0.1508358830834946 idk
# 259 0.13151445232790626 Frictional force, normal force, and gravity.
# 260 0.21148461392629717 When the ball is moving upward, it has a normal force, the force of gravity and it continues upwards to hit its peak to gain a velocity of zero
# 261 0.41190796311669575 Newton's second law. in which states that force equals mass times acceleration.
# 262 0.3478808249513777 Newton's first law states that an object moving at a constant velocity is either at rest or has a net force of zero.
# 263 0.16750889174323075 it is non zero
# 264 0.3735570865168631 The car and the truck exert the same force on each other due to newtons third law of each object action having an equal and opposite reaction
# 265 0.3260402425367065 Yes, Newtons first law says that if the net force on an object equals zero the object will move with a constant velocity in a straight line. This means that the meteor will move in a straight line.
# 266 0.24653421882489387 the force applied by the man pushing on the block and the force acting against it of static friction
# 267 0.24017237112206385 the net force is pulling the kid up
# 268 0.29497816737234517 The horazontal forces acting on the box are the mover pushing the box and friction pushing back against the box in the opposite direction of motion. The vertical forces are gravity keeping the box down on the ground, and the carpeted floor pushing up on the box. This problem exemplifies Newton's second law of motion, which states that all objects in motion must have forces working in opposite directions to one another in both the horazontal and vertical components.
# 269 0.18279377249290948 The meteor's motion is constant.
# 270 0.20293550938410532 the man pushing the box and the frictional force of the floor balance each other
# 271 0.3553921827316041 Newton's first law, as everything at rest or in motion will continue to be in rest or in motion unless an outside force is acted upon it, and there are no outside forces acting on it.
# 272 0.15058072458162294 The velocity is going down.
# 273 0.211598775311764 The force exerted on the winshield by the mosquito equqals the force exerted on the mosquito by the windshield
# 274 0.2515701654275268 An object at rest stays at rest unless acted upon by an outside force
# 275 0.19505277842465793 the net force acting on an object divided by its mass equals the resulting acceleration of that object
# 276 0.8278150711431923 second law
# 277 0.2112159670939476 if there is a zero net force on the object, the velocity will be constant
# 278 0.33388017704105233 newton's second law states that the net total of the forces in the horizontal direction must cause the box to accelerate. Because there is no net force in the vertical direction, the box does no move up or down. Because there is a net force in the horizontal plane, there must be movement along thr horizontal
# 279 0.16982696754052595 It will decrease
# 280 0.23293326587676788 the force will double
# 281 0.22836917133510753 The horizontal forces acting on the box that balance each other are the applied force that comes from the person poushing the box and the frictional force that comes from the moving on the floor. They are both opposite of each other so they balance each other.
# 282 0.25648156437472386 An object stays in motion or stays at rest unless acted upon by an external force.
# 283 0.09963638117202522 Net force equals mass times acceleration.
# 284 0.20589067487482407 AN OBJECT MOVES AT A CONSTANT VELOCITY IF THERE IS NON-ZERO NET FORCE
# 285 0.20610974928738077 The tension is equal to the force of gravity
# 286 0.21200271124404316 the force exerted on the winshield by the mosquito equals the force exerted on the mosquito by the windshield.
# 287 0.18630655373605187 The puck will move with a constant velocity in a straight line
# 288 0.5373032555149901 newton's law
# 289 0.1891800082639652 The acceleration will jump from zero to a non-zero value and the speed will consistantly increase.
# 290 0.20209357286778398 A force from the push, a force fo friction, a force of gravity, and a normal force
# 291 0.10798129515349095 It is at a constant velocity
# 292 0.2131600518487975 The normal force and the force of gravity balance each other out.
# 293 0.4832826199222906 Newtons first law, becuase his first law explains that everything in motion stays in motion and everything at rest stays at rest until a force acts on it.
# 294 0.27378395122399657 There is the force of gravity and the force applied from the player's hand. The motion of the ball is upward.
# 295 0.21751814382040333 The acceleration of the desk and its speed will increase after the mover doubles his push.
# 296 0.32600476236750425 Newton's first law is relevant to this problem because it explains that a constant non-zero force will have a constant mass and acceleration.
# 297 0.23280271262585372 The force exerted on the windshield by the mosquito and the force exerted on the mosquito by the windshield are equal but opposite
# 298 0.2267843025377725 the amounts of tension in the rope and the force of gravity pulling the child downwards balance out
# 299 0.03224634845411349 direction and magnitude.
# 300 0.3544998658180495 Newton's first law states that an object in motion will stay in motion unless a force is acted upon it, or an object that is stationary will remain stationary unless a force is applied to it.
# 301 0.582949769771552 newtons first law
# 302 0.20442975306398609 the force of the mosquito and the car have equal and oppisite reactions on each other
# 303 0.2657266539266021 The force the truck exerts on the car is the same as the force the car exerts on the truck but in opposite directions.
# 304 0.20938065333692954 there is a frictional force acting on the box.
# 305 0.2349230208957384 The truck speeding up is pushing with a greter force until it is able to push the speed at a constant velocity when their forces finally ballence each other out.
# 306 0.27813985251931517 The net forcer on the desk when the mover doubles his force is increased.
# 307 0.14992979957072705 Horizontal force from mover, kinetic frictional force, gravitational force, and normal force.
# 308 0.27412140744177976 the basketball is in free fall, therefore the only force acting on it is the gravitational force
# 309 nan sdf
# 310 0.0944379190004998 energy cannot be created or destroyed
# 311 0.18344445136181187 they both will remain constant unless acted upon
# 312 0.22186537814279214 The force exerted on the windshield by the mosquito equals the force exerted on the mosquito by the windshield.
# 313 0.1697765613273319 Kinetic friction and gravitational force are balanced by normal force and the force exerted by the man pushing the box.
# 314 0.24216487109350238 The force exerted on the windshield by the mosquito is equal in magnitude and opposite in direction to the force exerted on the mosquito by the windshield.
# 315 0.12059937689956174 THAT IS REMAINS CONSTANT
# 316 0.20321719885984954 The acceleration and speed increase as the mover doubles his force
# 317 0.20199086831650187 the force of the magnitude of the truck is greater than the magnitude of the smaller car
# 318 0.2622629192634982 The downward force of gravity is acting on the puck as well as the force from the pass.
# 319 0.30355823497233686 There is a normal force acting on the puck and a force of the pucks weight acting on the puck. These balance eachother out due to Newton's first law of motion. There is also the force of the hockey stick pushing the puck.
# 320 0.2680469831750728 the meteor will move in the direction of the net force acting on it
# 321 0.11293233087847271 slowing down
# 322 0.22187163428453016 The puck will move along the straight line and the speed of the puck will remain constant until a force acts on it to change its speed
# 323 0.23592370006562124 The floor is carpeted so you know that there is going to be friction involved, and because we are on Earth, then there is a gravitational force. The man is pushing the box so there is a pushing force, and because it is lying on the ground then there is a force that the ground is acting on the box.
# 324 0.43353784038611565 NEWTONS FIRST LAW IS RELEVANT BECAUSE NO FORCE IS ACTING ON IT
# 325 0.2273751300808838 THE NET FORCE IS ZERO
# 326 0.21709099205596227 the normal force and the force due to gravity. These are the two vertical foces.
# 327 0.3887012413485806 Newton's first law states that any object in rest or in motion will remain in rest or in motion unless an external force is given
# 328 0.2336270598228579 Gravity is pulling the box downwards, but the normal force is pushing upwards. The other force is that which the mover applies horizontally. Friction from the carpet acts opposite to the direction of the push that the mover applies
# 329 0.23980916929007248 The force exerted on the windshield by the mosquito and the force exerted on the mosquito by the windshield are equal and opposite as part of an action and reaction pair.
# 330 0.335718119492801 The meteor will move with the speed and direction that the rocket is pushing it. This is because Newton's second law of motion states that when a force is acting on an object, that object will move with the force being exerted upon it, unless some other force interupts the first one.
# 331 0.16638362153677952 The forces are anything that helps move an object at a constant speed.
# 332 0.2509289066366467 it moves in a straight line
# 333 0.2630941836184432 For every force there is an equal and opposite reaction. So the force exerted by the car on the bug is the same as the force of the bug on the car but in the opposite direction.
# 334 0.26758266884272336 When the mover doubles his force, there is no longer a balance so the net force is not zero anymore.
# 335 0.37357326527212975 Newtons second law is the where acceleration is equal to the net force divided by the mass of the object
# 336 0.03224634845411349 direction and magnitude
# 337 -0.016654072132793133 friction and pushing
# 338 0.12825877461783758 The speed of the rocket will remain constant.
# 339 0.23833180536936413 The total net force is doubled.
# 340 0.5406116638966959 Newton's first law is relevant.
# 341 0.2480920606582697 every force acting on an object has a force equal in magnitude but opposite in direction also acting on that same object
# 342 0.24471703820100504 The forces acting on the box are the force of the man pushing the box in a straight line and the force of friction from the carpet against the box.
# 343 0.11293233087847271 SLOWING DOWN
# 344 0.16846288277141944 The speed of the meteor will increase.
# 345 0.6506412163322772 newton's second law
# 346 0.3726780267924112 Newton's first law states an object in motion will remain in motion, and an object at rest will remain at rest unless acted on by an outside force.
# 347 0.21249577955145701 The horizontal forces acting on the box are the floor exerts a horizontal force due to friction on the boxu and the man pushing the box across the floor. These two forces balance each other out.
# 348 0.23667010865264124 THE FORCE OF GRAVITY IS ACTING ON IT
# 349 0.11197327006806629 they are equal
# 350 0.253733996230362 there is a normal force acting upwards on the puck and the force of gravity that pulls the puck down. These two forces cancel each other out
# 351 0.22448431149346287 The meteor will move at a constant rate. Since there is no gravity holding the meteor down, there are no other forces acting upon the meteor, therefore the meteor will move at a constant rate.
# 352 0.1498263055026805 the ball's velocity is increasing
# 353 0.20506173963962238 An equal force always balancing it out regardless of the different masses and weights.
# 354 0.2606519940098767 When the ball is midway between the player's hand and the ground, the gravitational force from the earth is acting on the ball, as well as the force from the bounce.
# 355 0.27223957284842304 The truck has an equal and opposite reaction the compact car's action on the truck.
# 356 0.2116016886717605 TWO OBJECTS COLIDE AND EXERT THE SAME AMOUNT OF FORCE
# 357 0.11352207022843765 action reaction
# 358 0.16085300623294488 gravity, friction, force of the push, and the normal force
# 359 0.22328244880219533 a downward force from the hand, a gravitational force and a normal force from the ground
# 360 0.22391341645893015 an object is at rest until acted upon by another force
# 361 0.22145221907525095 the desk will move faster because the additional force gives an Acceleration
# 362 0.12449560541629161 They balance each other.
# 363 0.16052398778424062 the forces exerted by each are equal
# 364 0.4349713580903843 Newton's third law states than any action force will have an equal and opposite reaction force
# 365 0.27239069707049374 The net force on the child would be zero because the forces acting on him are ballenced
# 366 0.4139434133514262 The magnitudes of the forces are equal to eachother due to Newton's third law of motion.
# 367 0.12109507304333958 The speed is not changing.
# 368 0.26014701655981903 since the truck is pushing on the car with a force, the same magnitude of force is pushing back
# 369 0.3560270868524446 It refers to newton's first law which states that an object at rest will remain at rest unless acted on by an outside force and an object in motion will remain in motion unless acted on by an outside force.
# 370 0.2640906157539131 the force acting from the car on the truck is greater than that of the truck on the car
# 371 0.5494162565739694 NEWTONS SECOND LAW IS RELEVANT
# 372 0.2079705686006772 both objects exert the same amount of force on each other
# 373 0.233670261384198 anaction force is equal to reaction force. the magnitude of the force will be equal, but in opposite direction
# 374 0.08619418973746804 the are balanced
# 375 0.14034776238134203 THE DESK IS ACCELERATING
# 376 0.26179129181554006 When it is moving upward, and in the air. The only force acting on the ball is gravity.
# 377 0.20963808623043353 There is a gravitational and normal force acting upon the puck
# 378 0.17273407832025706 net force and gravity
# 379 0.12730252365480066 the acceleration is positive
# 380 0.1521389591156381 The forces are acting upon each other are equal.
# 381 0.424846103848894 The forces are equal. Newton's third law states for every force there is an equal and opposite force.
# 382 0.23754191666203123 the puck will continue in a straight line at a constant velocity until a force is applied to it.
# 383 0.3475833277441552 the amount of tension in the rope is equal to the downward force of gravity acting on the child according to newtons third law of for every object action there is an equal and opposite reaction
# 384 0.23009741545344906 The meteor will continue to move at a constant velocity because the net force acting on it is zero.
# 385 0.21029053604170206 an object stays at rest or keep a constant velocity if the net force is zero
# 386 0.40498717462754985 Newton's third law states that for every action or force there is an equal and opposite reaction force. The car and truck are part of a reaction pair.
# 387 0.1687962248780565 it is zero
# 388 0.4023686720365778 The tension of the rope and the force of gravity both have equal reactions to one another as stated by Newton's third law of motion
# 389 0.5406116638966959 newton's first law is relevant
# 390 0.582949769771552 NEWTONS FIRST LAW
# 391 0.26156114009543774 The net force on the kid is in the upward position and acts on the rope.
# 392 0.1773629283244362 the meteors motion is positive
# 393 0.29088271329533794 Everything in motion stays in motion and everything at rest stays at rest until a force acts on the object.
# 394 0.19404950981501526 The magnitude of the mover's push is greater than the magnitude of the opposing frictional force acting on the desk.
# ...
# 605 0.08735457454489555 zero
# 606 0.2202704677177177 for every force that is acting on an object, there is a reaction force with same magnitude,but different direction.
# 607 0.21880627829388635 The net horizontal force is zero so the puck moves at a constant rate
# 608 0.238728522197057 The forces of the truck on to the car is equal to the forces of the car to the truck, but the magnitudes are opposite of each other
# 609 0.20796341825934356 the friction is opposing his pushing force, but it is less than the net force
# 610 0.235550019567078 the force that was exerted by the floor when the ball bounced and gravity
# 611 0.17242454895401446 The acceleration of the desk is non-zero and the speed is not constant.
# 612 0.22138122962833268 Any object at rest will remain at rest unless acted upon by an outside force or remain at a constant velocity unless acted upon by an outside force
# 613 0.1704952586398143 it is positive
# 614 0.20748710961542785 every action has an equal and opposite reaction
# 615 0.2820988933836753 The meteor will move with increasing speed due to the force applied. Newton's second law states tha force is equal to mass times acceleration so the meteor must be accelerating to have a force applied. Since a force is applied to an object at rest, the object will increase speed. Force is equal to mass times acceleration.
# 616 0.16833943030548842 The trajector and speed of the puck is constantly changing as it is being hit.
# 617 0.23636633075912825 the meteor has a net zero force acting on it
# 618 0.2228821257959136 The gravitational force from the earth of the boxy and the normal force from the flooe on the box balance each other.
# 619 0.24446154652243937 The forces will equal one another
# 620 0.1620176501108792 Gravity, the mover, friction, and normal force are acting on the box.
# 621 0.19711292091930718 The total or net force is greater than the frictional force.
# 622 0.03224634845411349 magnitude and direction
# 623 0.21151594812307686 Graviational force is acting on the ball and its speed is decreasing at a constant rate.
# 624 0.3613067986851128 Newton's second law states that the force of an object is equal to the mass multiplied by the acceleration of the object.
# 625 0.17596758673982357 that the acceleration will also double
# 626 0.08725003701330139 equal to his mass times acceleration
# 627 0.23382977781745956 The acceleration is going in the direction of the net force.
# 628 0.5582974263608013 newton's third law becomes relevant
# 629 0.13610131984799564 The magnitudes and amounts of the forces they exert on each other are equal.
# 630 0.24597799296605663 The meteor will continue to move in the direction in which the initial force was applied, but it will gradually slow down.
# 631 0.7484078425845344 Newton's 3rd law
# 632 0.24594482631268713 The net force does not necessarily double but it does increase.
# 633 0.23214469083562606 A frictional force is acting on the object against the force the mover is putting on the box. The normal force balances out the force of weight.
# 634 0.14961172670441877 it will move at a constant acceleration
# 635 0.25767622770648874 There is zero net force on the object once the rocket stops pushing the meteor, therefore the object in motion will remain in motion
# 636 0.1712143364331691 it is decreasing.
# 637 0.1928777507153572 the ball is slowing down
# 638 0.3038179673029053 The meteor will continue to move with constant velocity. This is because there are no outside forces acting upon it, and due to Newtons first law, an object will continue to stay in said motion with constant velocity unless and outside force is acting upon it.
# 639 0.14184531410170054 they are the same
# 640 0.2352386274732931 The forces acting on the box are the weight of the box, the normal force of the carpeted floor pushing against the box, the frictional force of the carpet against the box, and the force of the push by the mover
# 641 0.11165327332169003 the speed is constant
# 642 0.07438023045536996 force equals mass times acceleration
# 643 0.20157417698803987 The speed of the puck will remain constant since there is no frictional force
# 644 0.2497683386031235 The mosquito is applying a force to the windshield and the windshield is applying the same force to the mosquito, but in a different direction.
# 645 0.216136122593451 OBJECTS WITH STAYS AT REST IF NO FORCES ARE APPLIED
# 646 nan sdf
# 647 0.14268036862171884 it will be constant
# 648 0.2446022392088434 The large truck exerts a greater force because it has a greater mass than the small car. A larger force is pushing on the car from the truck and a smaller force is pushing back on the truck from the car.
# 649 0.07658102469255315 it has a constant velocity
# 650 0.7488044882285937 Newtons 3rd law
# 651 0.20653361697293224 It will remain the same
# 652 0.7597156917447091 Newton's 1st and 2nd laws
# 653 0.3073777683192089 If the mover doubles his force, the speed of the desk will increase because according to Newton's first law force equals mass times acceleration. Therefore, if force is increased, but mass of the object stayed the same, the speed would have to increase.
# 654 0.2346652859526851 The net force on the kid is non-zero, and the kid is moving with a CONSTANT velocity in a STRAIGHT LINE from the tension in the rope.
# 655 0.18006177455237882 gravity and forward force and normal force
# 656 0.34247255937995114 THE METEOR WILL BEGIN TO SLOW AFTER THE ROCKET STOPS PUSHING DUE TO NEWTONS FIRST LAW.
# 657 0.17648518935374286 All forces acting on the object are important.
# 658 0.16035848349662063 it is greater than the frictional force
# 659 0.3297963008016903 The speed of the desk will increase. Originally the forces cancel eachother out since the desk moves at a constant velocity. This is explained by Newton's first law of motion. However, when the force is doubled, the forces no longer cancel eachother out, and the speed of the desk will increase.
# 660 0.20546281759389415 it is pointed up
# 661 0.2169351729233421 the force of the man pushing and a frictional force and a normal force and the force of the weight of the box
# 662 0.2744362549377308 It states that the object states that objects tend to stay in motion or at rest unless acted pn by other forces
# 663 0.18666791872072033 Net Force
# 664 0.1303353469596487 Change in speed and direction.
# 665 0.28032023045209875 The net force on the kid will be zero because gravity and the ground are both acting on the boy causing the force to equal zero
# 666 0.2101004363415759 the net forces are the sum of all the forces acting on the object
# 667 0.44317794925461607 Newton's third law explains that every action has an opposite and equal reaction.
# 668 0.2541165946960244 There are several forces acting on the box. There is the force being applied by the mover, a force resisting motion, gravitational force, and the normal force between the box and the ground. The normal force and the gravitational force balance each other out.
# 669 0.23128257972942778 There is zero net force on the object, therefore it will not slow down once the rocket stops pushing.
# 670 0.3196230703691183 The second law of Newton's explains that the net forces acting on an object equals to the mass of the object multiplied by the acceleration of the object.
# 671 0.2533550442419777 When the ball is moving upward, a downward force caused by gravity is acting on the ball. There is also a normal force, otherwise known as a ground reaction force, acting upward on the ball. While the ball is midway between the player's hand and the ground, the ball is moving upward. This is happened because the normal force is GREATER than the gravitational force acting on the ball.
# 672 0.0901785297250888 They are zero.
# 673 0.14184531410170054 they are the same
# 674 0.2145022917762235 The tension force is higher than the force of gravity.
# 675 0.24649025339943081 The force of the mosquito on the windshield equals to the force of the windshield on the mosquito in opposite directions.
# 676 0.9999999999999999 2nd law
# 677 0.49489920899531553 newton's second law. F=Ma
# 678 0.21828627895934996 the force exerted on the windshield by the mosquito is less than the force exerted on the mosquito by the windshield
# 679 0.28828650801538047 Newton's first law is useful for this problem because it states force equals mass times accerleration. Clearly if mass is the same, but force is increased, acceleration has to increase as well.
# 680 0.13964098506194492 The acceleration of the meteor is increasing.
# 681 0.20978166093456868 it increases
# 682 0.6126951748506334 Newtons third law
# 683 0.23984091828602583 THE METEOR WILL KEEP MOVING UNTIL THE NET FORCES EQUAL ZERO
# 684 0.2243395960451051 the force of friction and the force of the man hing on the box
# 685 0.15200759752251317 it speeds up
# 686 0.30623386822399 the car and truck, according to newtons second law, exert equal and opposite forces on one another. The magnitude of the force exerted by the truck is equal to the force exerted by the car. The amount of force exerted by the truck however, is greater than the amount of force exerted by the car.
# 687 0.22729679711535405 The force of the bug hitting the window is much less than the force that the window exerts on the bug
# 688 0.1544292138969794 the normal force, frictional force, gravitational force
# 689 0.02356382540381325 Normal, frictional, and weight.
# 690 0.1317094318644478 it is directed downwards
# 691 0.2268158316047125 The speed on the puck is constant, and it will move in a straight line.
# 692 0.6174531675159592 Newton's first law.
# 693 0.23504575872116626 The forces are gravity pulling down and the floor pulling up in the vertical component, and the force of the mover pushing the box in one direction while the force of frictions pushing back against that movement in the horazontal component.
# 694 0.43257068283386146 Newton's third law explains that for every action there is an equal and opposite reaction.
# 695 0.12371737303198005 IT MOVES AT A CONSTANT VELOCITY
# 696 0.18271386854497196 The meteor will accelerate in the same direction as the rocket.
# 697 0.13277015217345184 THE METEOR WILL MOVE WITH A CONSTANT VELOCITY
# 698 0.24490015909624893 Since the net force acting upon the object is zero and it was already in motion it will move at a constant velocity
# 699 0.16463277901462964 all of them...
# 700 0.21828627895934996 The force exerted on the windshield by the mosquito is less than the force exerted on the mosquito by the windshield
# 701 0.25632839205393393 when the mover doubles his force, the net force will greater and the table will begin to accelerate
# 702 0.14309427325274618 Acceleration provides the magnitude and the direction of the ball
# 703 0.24792242295132175 It will be proportional to the net force.
# 704 0.2231608913452164 equal to the net force divided by the mass
# 705 0.2654438515542062 The net force will be a greater, positive integer after the force is doubled.
# 706 0.2515998882715608 The force exerted by the car onto the truck is equal in magnitude and opposite in direction compared to the force exerted by the truck onto the car.
# 707 0.18197919023400844 the horizontal force is balanced.
# 708 0.10237125390237013 It provides speed and direction.
# 709 0.23725287386294258 When the ball is moving upward it is in free-fall and it is affected by the Earth's gravitational pull.
# 710 0.22751477287877026 The speed is also doubled because the force is doubled.
# 711 0.230959084669794 the applied force and fricitonal force balance each other.
# 712 0.28924799773003435 the force of the truck on the car is equal to the force of the car on the truck
# 713 0.2088843506093204 the tension in the rope is greater than the downward force of gravity
# 714 0.13428760140155624 the meteor keeps moving
# 715 0.2242830941052343 there is a non-zero net force being applied to the meteor so it will move at a constant speed and direction
# 716 0.11197327006806629 They are equal.
# 717 0.19503601314996027 both forces are equal in magnitude and opposite in direction
# 718 0.5179720461607481 Newton's third law of motion states that this is true
# 719 0.18546572910029635 It will have a constant speed in a straight line.
# 720 0.41487467950941054 Newton's second law tells me that the acceleration is moving in a positive direction.
# 721 0.23877538093226527 The amount of tension in the rope is greater than the downward force of gravity acting on the child.
# 722 0.2083866851798932 The forces that applied to the box is the force from the mover, gravity, the normal, and friction
# 723 0.17494906909245303 They were equal in magnitude but opposite in direction.
# 724 nan sfsdf
# 725 0.23441575434594777 The direction of the ball's acceleration is downward because the net force of the ball at that point in time is only the gravitational acceleration which is negative.
# 726 0.29404563702195063 The net force is not equal to zero when the mover doubles his force.
# 727 0.23071495243152582 The forces acting on the box are friction from the carpet, the pushing force by the man, the gravitational force from Earth, and the normal force from the ground on the box. The gravitational and normal force balance each other out.
# 728 0.13253722226333595 The ball's velocity is changing.
# 729 0.17295763612274406 equal and opposite forces
# 730 0.2234714192614812 The speed of the desk will increase as a result of doubling the force. Force is directly proportional to acceleration. Increasing the force on the desk will increase the acceleration of the desk.
# 731 0.1704952586398143 It is positive.
# 732 0.16660520945584997 The ball's velocity is slowing down.
# 733 0.2206997704688456 a force by the mover is acting on the box as well as a normal force and gravitational force.
# 734 0.2628379082331548 an object at rest stays at rest. an object in motion stays in motion in a straight line with constant velocity unless acted upon by some external force
# 735 0.20478545764503442 the amount of tension in the rope is greater than the force of gravity
# 736 0.267784804049542 in the direction of the force acting on it
# 737 0.16492428053970717 acceleration is net force divided by mass
# 738 0.16159558550711758 the ball's velocity is decreasing
# 739 0.11076795431700394 The balls velocity is decreasing.
# 740 0.7056166330873999 2nd
# 741 0.23969880781887506 The net force on the object will not be zero when the mover doubles his force. He will no longer be moving at a constant velocity. His speed will increase.
# 742 0.22729585185378792 The action of the mosquito hitting the windshield has an equal and opposite reaction of the windshield hitting the mosquito.
# 743 0.13731333531178808 GRAVITY, THE PUSH, FRICTION AND THE Fn
# 744 0.1676600011622231 force is eqal to the weight
# 745 0.15052500507902095 THE METEOR WILL ACCELERATE AND THEN MOVE WITH A CONSTANT VELOCITY
# 746 0.21133033917316052 The forces acting on the ball are gravity and the normal force from the ball. The ball moves verticallt upward at a constant velocity.
# 747 0.17770741748103297 it will increase
# 748 0.19519312615937973 THE TENSION FORCE IS GREATER THAN THE FORCE OF GRAVITY
# 749 0.2146865841821603 The speed of the desk increases by double.
# 750 0.41575772126241783 newtons first law explains net force as the sum of forces
# 751 0.20038404662082035 The push is going to be greater than the opposing forces.
# 752 0.21251950202129818 The ball's acceleration is diminishing as it returns to the player's hand.
# 753 0.11887305191171724 They are equall but opposite
# 754 0.25815079872798 It will be in the same direction as the applied net force
# 755 0.13201843510611663 The meteor's velocity will be increasing
# 756 0.14757317356739783 The metor's motion is linear and that the magnitude of the velocity of the meteor is constantly increasing.
# 757 0.23570029177123186 Gravity is acting on the puck as it is moving on the ice between the two players. The motion of the puck is in a straight line.
# 758 0.2281937122713391 It says that the meteor is at a constant acceleration, and will continue to be so until another force changes this.
# 759 0.14184531410170054 they are the same

# %%
word2vec.wmdistance(phrase1, phrase2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-136-09a3506dc639> in <module>
# ----> 1 word2vec.wmdistance(phrase1, phrase2)
#
# /anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in wmdistance(self, document1, document2)
#     715         # If pyemd C extension is available, import it.
#     716         # If pyemd is attempted to be used, but isn't installed, ImportError will be raised in wmdistance
# --> 717         from pyemd import emd
#     718
#     719         # Remove out-of-vocabulary words.
#
# ModuleNotFoundError: No module named 'pyemd'

# %%
landmarks.head()
# Out:
#       pd_hash     qu_hash  label                                                                                                                                                                                                                                                   answer
# 0  5059c9cfbb  27570f5d10      0                                 An object at rest will stay at rest and at object moving with constant velocity in a straight line will continue moving with constant velocity in a straight line as long as the net force acting on the object is zero.
# 0  5059c9cfbb  27570f5d10      0  If all the forces acting on an object add up to zero (accounting for the direction of the forces and not just their magnitude) then the acceleration of that object also has to be zero. It can move at a constant speed but it cannot be accelerating.
# 0  5059c9cfbb  27570f5d10      0                                                                                                                                                            When the object is in equilibrium or velocity is constant, the sum of all forces will equal .
# 1  abb3be1545  c9b7df0ef8      0                                                                                                             When the rocket stops pushing, no forces are acting on the meteor anymore and therefore will move with constant velocity in a straight line.
# 1  abb3be1545  c9b7df0ef8      0                                                                                                                                                           When the rocket stops pushing, the meteor will move with constant velocity in a straight line.

# %%
with open(os.path.join("munge", "landmarks.txt"), 'w') as f:
    f.write('pd_hash\tqu_hash\tlabel\tanswer\tembedding\n')
    for i in range(len(landmarks)):
        pd_hash = landmarks.iloc[i]['pd_hash']
        qu_hash = landmarks.iloc[i]['qu_hash']
        label = landmarks.iloc[i]['label']
        answer = landmarks.iloc[i]['answer']
        emb = get_embeddings(preprocess(landmarks.iloc[i]['answer']))
        emb = ','.join(map(str, emb))
        f.write("%s\t%s\t%s\t%s\t%s\n" %(pd_hash, qu_hash, label, answer, emb))

# %%
emb = get_embeddings(preprocess(landmarks.iloc[0]['answer']))
s= ','.join(map(str, emb))
type(s)
# Out:
# str

# %%
extract_reference_answers(landmarks_ra.iloc[0]['reference_answers'])
# Out:
# ['An object at rest will stay at rest and at object moving with constant velocity in a straight line will continue moving with constant velocity in a straight line as long as the net force acting on the object is zero.',
#  'If all the forces acting on an object add up to zero (accounting for the direction of the forces and not just their magnitude) then the acceleration of that object also has to be zero. It can move at a constant speed but it cannot be accelerating.',
#  'When the object is in equilibrium or velocity is constant, the sum of all forces will equal .']

# %%
landmarks_ra['ra_exploded'] = landmarks_ra['reference_answers'].apply(extract_reference_answers)
landmarks_ra.head()
# Out:
#       pd_hash     qu_hash                                  reference_answers  \
# 0  5059c9cfbb  27570f5d10  1:  An object at rest will stay at rest and at...
# 1  abb3be1545  c9b7df0ef8  1:  When the rocket stops pushing, no forces a...
# 2  d0331a86c9  37b9d25827  1:  The desk will move with constant accelerat...
# 3  a5b241c8bc  52e3695922  1:  The ball is slowing down at a constant rat...
# 4  d0331a86c9  64a1152f6d  1:  The desk moves with increasing velocity. 2...
#
#    label                                        ra_exploded
# 0      1  [An object at rest will stay at rest and at ob...
# 1      1  [When the rocket stops pushing, no forces are ...
# 2      2  [The desk will move with constant acceleration...
# 3      0  [The ball is slowing down at a constant rate.,...
# 4      3  [The desk moves with increasing velocity., The...

# %%
landmarks_ra.iloc[0:1].explode('ra_exploded')
# Out:
#       pd_hash     qu_hash                                  reference_answers  \
# 0  5059c9cfbb  27570f5d10  1:  An object at rest will stay at rest and at...
# 0  5059c9cfbb  27570f5d10  1:  An object at rest will stay at rest and at...
# 0  5059c9cfbb  27570f5d10  1:  An object at rest will stay at rest and at...
#
#    label                                        ra_exploded
# 0      1  An object at rest will stay at rest and at obj...
# 0      1  If all the forces acting on an object add up t...
# 0      1  When the object is in equilibrium or velocity ...

# %%
pd.__version__
# Out:
# '0.24.2'
